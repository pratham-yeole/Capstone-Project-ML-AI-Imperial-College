# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern, WhiteKernel, ConstantKernel as C
from sklearn.preprocessing import power_transform
from scipy.stats import norm

# %% [markdown]
# # **Function 6** - Cake Recipe Optimisation (5D)
#
# - Optimising a cake recipe using a black-box function with five ingredient inputs
#     - E.g., example flour, sugar, eggs, butter and milk.
#
# - Each recipe is evaluated with a combined score based on flavour, consistency, calories, waste and cost, where each factor contributes negative points as judged by an expert taster.
#
# - The total score is negative by design.
#
# - **Goal** - bring the score as close to zero as possible.
#
# **Input** - 5D array
# **Output** - 1D array
# **Optimisation Goal** - Maximise (target: 0.0)
# **All-time best:** -0.128 at [0.593, 0.387, 0.658, 0.780, 0.074] (Week 5)

# %%
# Load current cumulative dataset (original + prior weekly updates) for Function 6
X = np.load('/Users/prathamyeole/Library/CloudStorage/OneDrive-Personal/Imperial - Machine Learning and Artifical Intelligence Certification/Capstone/Weekly Capstone Updates and Comments/Week 1/Initial_data_points_starter/initial_data/function_6/initial_inputs.npy')
Y = np.load('/Users/prathamyeole/Library/CloudStorage/OneDrive-Personal/Imperial - Machine Learning and Artifical Intelligence Certification/Capstone/Weekly Capstone Updates and Comments/Week 1/Initial_data_points_starter/initial_data/function_6/initial_outputs.npy')

# New data from Week 11 (Function 6)
X_w11_new_point = np.array([0.538511, 0.3879, 0.647756, 0.760736, 0.131331], dtype=np.float64)
Y_w11_new_point = np.array([-0.19203380674064138], dtype=np.float64)

# Append the new data point
X_updated = np.vstack((X, X_w11_new_point.reshape(1, -1)))

# Remove duplicate X rows (if point already exists)
X_unique, unique_indices = np.unique(X_updated, axis=0, return_index=True)

Y_all = np.append(Y, Y_w11_new_point)
Y_updated = Y_all[unique_indices]

# Save updated arrays
np.save('/Users/prathamyeole/Library/CloudStorage/OneDrive-Personal/Imperial - Machine Learning and Artifical Intelligence Certification/Capstone/Weekly Capstone Updates and Comments/Week 1/Initial_data_points_starter/initial_data/function_6/initial_inputs.npy', X_unique)
np.save('/Users/prathamyeole/Library/CloudStorage/OneDrive-Personal/Imperial - Machine Learning and Artifical Intelligence Certification/Capstone/Weekly Capstone Updates and Comments/Week 1/Initial_data_points_starter/initial_data/function_6/initial_outputs.npy', Y_updated)

print("Updated Inputs (X) - Function 6: ", X_unique)
print("Updated Outputs (Y) - Function 6: ", Y_updated)
# Out:
# Updated Inputs (X) - Function 6:  [[2.17353077e-02 4.28084240e-01 8.35939437e-01 4.89488659e-01
#   5.11081735e-01]
#  [1.25720155e-01 8.62724692e-01 2.85443322e-02 2.46605272e-01
#   7.51206241e-01]
#  [1.26678917e-01 2.91470301e-01 6.45284767e-02 6.80514603e-01
#   8.92819191e-01]
#  [1.45110786e-01 8.96684598e-01 8.96322235e-01 7.26271537e-01
#   2.36271991e-01]
#  [1.64117000e-01 2.15391000e-01 4.79099000e-01 7.26337000e-01
#   6.00000000e-02]
#  [2.42384347e-01 8.44099972e-01 5.77809099e-01 6.79021284e-01
#   5.01952888e-01]
#  [2.58905574e-01 7.93677708e-01 6.42113905e-01 1.96673464e-01
#   5.93103177e-01]
#  [4.32165933e-01 7.15617813e-01 3.41819103e-01 7.04999881e-01
#   6.14961845e-01]
#  [4.39344264e-01 6.98923833e-01 4.26820222e-01 1.09476085e-01
#   8.77888468e-01]
#  [4.41233000e-01 9.98122000e-01 1.24500000e-03 5.56711000e-01
#   3.21098000e-01]
#  [4.61344000e-01 3.23423000e-01 8.03851000e-01 9.69268000e-01
#   2.51090000e-02]
#  [4.87084000e-01 1.49390000e-02 9.99330000e-01 9.73696000e-01
#   9.98860000e-02]
#  [4.97821000e-01 3.31178000e-01 6.38314000e-01 7.67495000e-01
#   1.06570000e-02]
#  [5.00522000e-01 3.44002000e-01 6.12748000e-01 7.34912000e-01
#   9.03730000e-02]
#  [5.07314000e-01 3.94923000e-01 7.91626000e-01 6.39115000e-01
#   4.73920000e-02]
#  [5.36796903e-01 3.08780907e-01 4.11879285e-01 3.88225177e-01
#   5.22528304e-01]
#  [5.38511000e-01 3.87900000e-01 6.47756000e-01 7.60736000e-01
#   1.31331000e-01]
#  [5.92613000e-01 3.86959000e-01 6.57734000e-01 7.80318000e-01
#   7.36990000e-02]
#  [5.98021000e-01 4.42586000e-01 6.94937000e-01 9.10736000e-01
#   1.00000000e-06]
#  [6.18812299e-01 3.31802137e-01 1.87287868e-01 7.56238474e-01
#   3.28834798e-01]
#  [6.29307895e-01 8.03483678e-01 8.11408439e-01 4.56131858e-02
#   1.10624462e-01]
#  [7.27708000e-01 3.35856000e-01 7.85846000e-01 7.77106000e-01
#   2.30214000e-01]
#  [7.28186105e-01 1.54692570e-01 7.32551669e-01 6.93996509e-01
#   5.64013105e-02]
#  [7.29522610e-01 7.48106200e-01 6.79774641e-01 3.56552279e-01
#   6.71053683e-01]
#  [7.57594355e-01 3.55831415e-01 1.65228997e-02 4.34207205e-01
#   1.12433044e-01]
#  [7.70620242e-01 1.14403744e-01 4.67799319e-02 6.48324285e-01
#   2.73549053e-01]
#  [7.82879823e-01 5.36335859e-01 4.43283557e-01 8.59699826e-01
#   1.03259907e-02]
#  [7.84958094e-01 9.10682349e-01 7.08120104e-01 9.59225429e-01
#   4.91149586e-03]
#  [9.21776198e-01 9.31871216e-01 4.14876370e-01 5.95057266e-01
#   7.35625686e-01]
#  [9.45069068e-01 2.88459051e-01 9.78805764e-01 9.61655587e-01
#   5.98015936e-01]
#  [9.57739669e-01 2.35668572e-01 9.91458496e-02 1.56805934e-01
#   7.13173731e-02]]
# Updated Outputs (Y) - Function 6:  [-1.35668211 -2.57116963 -1.74688209 -1.23378638 -0.68442135 -1.20995524
#  -1.70255784 -1.29424696 -2.0184254  -1.77750875 -0.51170708 -0.94759224
#  -0.25085626 -0.16189869 -0.43136136 -1.14478485 -0.19203381 -0.12781661
#  -0.53162631 -0.82923655 -1.62283895 -0.60482914 -0.71426495 -1.67219994
#  -1.30911635 -1.53605771 -0.93575656 -1.24704893 -2.15576776 -1.69434344
#  -1.91267714]

# %% [markdown]
# ## **Output Analysis**
#
# - This week I got the output of -0.192 at [0.539, 0.388, 0.648, 0.761, 0.131], this was a really strong recovery from last week's poor output of -0.684.
#
#     - The x1 (0.539) and x2 (0.388) floor constraints introduced in w11 kept the recipe in a sensible range.
#     - x2=0.388 is almost exactly the w5 best (0.387).
#     - x5=0.131 is higher than the w5 best (0.074) but the score is still competitive at -0.192 versus the all-time best -0.128.
#
# - **Real-World Implication:** The floor constraints worked exactly as intended as they prevented the acquisition from exploring the uninformative low-ingredient region that caused the w10 disaster.
#     - The w11 recipe [0.539, 0.388, 0.648, 0.761, 0.131] is essentially a moderately good cake: ingredients in sensible proportions but with slightly too much milk (x5) and slightly not enough butter (x4).
#
# - **Model Clues:** x4 at 0.761 vs the w5 best 0.780, and x5 at 0.131 vs 0.074, are the two remaining gaps.
#     - w12 will keep all floor constraints and re-centre precisely on the w5 best coordinates.

# %% [markdown]
# ## **Bayesian Optimisation** - Gaussian Process Regressor
#
# - **Model:** Matern (nu=2.5) + WhiteKernel + Yeo-Johnson.
#
# - **On Neural Networks:** A 5D recipe optimisation with ~25 data points is not a viable NN surrogate candidate.
#     - The dimensionality-to-data ratio is too poor.
#     - The GP with constraints is working as we saw a slight improvement last week.

# %%
Y_transformed = power_transform(Y_updated.reshape(-1, 1), method='yeo-johnson').ravel()

print('Original Y:', Y_updated)
print('Transformed Y:', Y_transformed)

kernel = Matern(nu=2.5) + WhiteKernel(noise_level=1e-5)

model = GaussianProcessRegressor(
    kernel=kernel,
    n_restarts_optimizer=20)
    
model.fit(X_unique, Y_transformed)
# Out:
# Original Y: [-1.35668211 -2.57116963 -1.74688209 -1.23378638 -0.68442135 -1.20995524
#  -1.70255784 -1.29424696 -2.0184254  -1.77750875 -0.51170708 -0.94759224
#  -0.25085626 -0.16189869 -0.43136136 -1.14478485 -0.19203381 -0.12781661
#  -0.53162631 -0.82923655 -1.62283895 -0.60482914 -0.71426495 -1.67219994
#  -1.30911635 -1.53605771 -0.93575656 -1.24704893 -2.15576776 -1.69434344
#  -1.91267714]
# Transformed Y: [-0.33980308 -2.07703374 -0.92180502 -0.1507378   0.73592476 -0.11372396
#  -0.85698427 -0.24412505 -1.3124209  -0.96641384  1.03163428  0.30196038
#   1.49805724  1.66352485  1.17256694 -0.01189574  1.60706585  1.72790222
#   0.99703968  0.49483545 -0.73960553  0.87102688  0.68575593 -0.81240713
#  -0.26698046 -0.61062423  0.32108922 -0.17128632 -1.50601216 -0.844937
#  -1.16158744]
# GaussianProcessRegressor(kernel=Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1e-05),
#                          n_restarts_optimizer=20)

# %% [markdown]
# ## **Acquisition Function**
#
# - **Key change:** Retain all three floor constraints (x1≥0.45, x2≥0.30, x5≥0.06).
#     - Re-centre on the W5 all-time best [0.593, 0.387, 0.658, 0.780, 0.074] with std=0.02.
#
# - The W11 result being close to the W5 profile confirms this is the right neighbourhood.

# %%
def expected_improvement(X, model, y_max, xi=0.01):
    mu, sigma = model.predict(X, return_std=True)
    sigma = sigma.reshape(-1, 1); mu = mu.reshape(-1, 1)

    with np.errstate(divide='warn'):
        improvement = mu - y_max - xi
        Z = improvement / sigma
        ei = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 0.0] = 0.0
    return ei

w5_best = np.array([0.592613, 0.386959, 0.657734, 0.780318, 0.073699])

x_grid = np.random.normal(loc=w5_best, scale=0.02, size=(9000, 5))
x_uniform = np.random.uniform(0, 1, size=(1000, 5))

x_grid = np.vstack([x_grid, x_uniform])

# Floor constraints from 11 weeks of empirical evidence
x_grid[:, 0] = np.maximum(x_grid[:, 0], 0.45)  # x1 floor
x_grid[:, 1] = np.maximum(x_grid[:, 1], 0.30)  # x2 floor
x_grid[:, 4] = np.maximum(x_grid[:, 4], 0.06)  # x5 floor

x_grid = np.clip(x_grid, 0, 1)

y_max = np.max(Y_transformed)

ei_values = expected_improvement(x_grid, model, y_max, xi=0.01)
next_query = x_grid[np.argmax(ei_values)]

print(f'Best coordinates: {w5_best}')
print(f'Strategic Week 12 Query (Function 6): {next_query[0]:.6f}-{next_query[1]:.6f}-{next_query[2]:.6f}-{next_query[3]:.6f}-{next_query[4]:.6f}')
# Out:
# Best coordinates: [0.592613 0.386959 0.657734 0.780318 0.073699]
# Strategic Week 12 Query (Function 6): 0.555002-0.363159-0.636987-0.758428-0.126452

# %% [markdown]
# ## **Visualisation**

# %%
running_max = np.maximum.accumulate(Y_updated)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(Y_updated, marker='o', color='steelblue', linewidth=1.5, label='Weekly output')
axes[0].plot(running_max, marker='s', color='green', linewidth=2, linestyle='--', label='Running best')
axes[0].set_title('Function 6 — Output History')
axes[0].set_xlabel('Iteration')
axes[0].set_ylabel('Output')
axes[0].legend()
axes[0].grid(True, linestyle='--', alpha=0.5)

axes[1].plot(Y_transformed, marker='o', color='darkorange', linewidth=1.5)
axes[1].set_title('Function 6 — Transformed Output (GP Internal View)')
axes[1].set_xlabel('Iteration')
axes[1].set_ylabel('Yeo-Johnson Transformed Output')
axes[1].grid(True, linestyle='--', alpha=0.5)

plt.suptitle('Function 6 — Week 12', fontsize=13)
plt.tight_layout()
plt.show()
